# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load (Remember to Change These)
mouse_drug_data_to_load = "data/mouse_drug_data.csv"
clinical_trial_data_to_load = "data/clinicaltrial_data.csv"

# Read the Mouse and Drug Data and the Clinical Trial Data
mouse_drug_df = pd.read_csv(mouse_drug_data_to_load)
clinical_trial_df = pd.read_csv(clinical_trial_data_to_load)



# Combine the data into a single dataset
df = pd.merge(mouse_drug_df, clinical_trial_df, on="Mouse ID")

# Display the data table for preview
df
# Out:
#      Mouse ID      Drug  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0        f234  Stelasyn          0           45.000000                 0
# 1        f234  Stelasyn          5           47.313491                 0
# 2        f234  Stelasyn         10           47.904324                 0
# 3        f234  Stelasyn         15           48.735197                 1
# 4        f234  Stelasyn         20           51.112713                 2
# ...       ...       ...        ...                 ...               ...
# 1901     j235   Placebo          0           45.000000                 0
# 1902     j235   Placebo          5           46.588820                 0
# 1903     j235   Placebo         10           48.018788                 1
# 1904     j235   Placebo         15           51.161138                 1
# 1905     j235   Placebo         20           52.942902                 1
#
# [1906 rows x 5 columns]

# %% [markdown]
# ## Tumor Response to Treatment

# %%
# Store the Mean Tumor Volume Data Grouped by Drug and Timepoint 
df_group = df[["Drug", "Timepoint", "Tumor Volume (mm3)"]]
df_group = df.groupby(["Drug", "Timepoint"])


# Convert to DataFrame
df_grouped = df_group.mean().drop(["Metastatic Sites"], axis=1)


# Preview DataFrame
df_grouped = df_grouped.reset_index()
df_grouped.head(50)
# Out:
#          Drug  Timepoint  Tumor Volume (mm3)
# 0   Capomulin          0           45.000000
# 1   Capomulin          5           44.266086
# 2   Capomulin         10           43.084291
# 3   Capomulin         15           42.064317
# 4   Capomulin         20           40.716325
# 5   Capomulin         25           39.939528
# 6   Capomulin         30           38.769339
# 7   Capomulin         35           37.816839
# 8   Capomulin         40           36.958001
# 9   Capomulin         45           36.236114
# 10   Ceftamin          0           45.000000
# 11   Ceftamin          5           46.503051
# 12   Ceftamin         10           48.285125
# 13   Ceftamin         15           50.094055
# 14   Ceftamin         20           52.157049
# 15   Ceftamin         25           54.287674
# 16   Ceftamin         30           56.769517
# 17   Ceftamin         35           58.827548
# 18   Ceftamin         40           61.467895
# 19   Ceftamin         45           64.132421
# ...

# %%
# Store the Standard Error of Tumor Volumes Grouped by Drug and Timepoint
sem_df = df_group.sem()
# Convert to DataFrame
sem_df = sem_df.drop(["Metastatic Sites", "Mouse ID"], axis=1)
sem_df = sem_df.reset_index()
# Preview DataFrame
sem_df
# Out:
#          Drug  Timepoint  Tumor Volume (mm3)
# 0   Capomulin          0            0.000000
# 1   Capomulin          5            0.448593
# 2   Capomulin         10            0.702684
# 3   Capomulin         15            0.838617
# 4   Capomulin         20            0.909731
# ..        ...        ...                 ...
# 95  Zoniferol         25            0.602513
# 96  Zoniferol         30            0.800043
# 97  Zoniferol         35            0.881426
# 98  Zoniferol         40            0.998515
# 99  Zoniferol         45            1.003576
#
# [100 rows x 3 columns]

# %%
# Minor Data Munging to Re-Format the Data Frames
df_grouped = df_grouped.pivot(index="Timepoint", columns="Drug")
# Preview that Reformatting worked
df_grouped
# Out:
#           Tumor Volume (mm3)                                              \
# Drug               Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol
# Timepoint
# 0                  45.000000  45.000000  45.000000  45.000000  45.000000
# 5                  44.266086  46.503051  47.062001  47.389175  46.796098
# 10                 43.084291  48.285125  49.403909  49.582269  48.694210
# 15                 42.064317  50.094055  51.296397  52.399974  50.933018
# 20                 40.716325  52.157049  53.197691  54.920935  53.644087
# 25                 39.939528  54.287674  55.715252  57.678982  56.731968
# 30                 38.769339  56.769517  58.299397  60.994507  59.559509
# 35                 37.816839  58.827548  60.742461  63.371686  62.685087
# 40                 36.958001  61.467895  63.162824  66.068580  65.600754
# 45                 36.236114  64.132421  65.755562  70.662958  69.265506
#
#
# Drug         Placebo   Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# ...

# %%
# Generate the Plot (with Error Bars)
drug = [
    "Capomulin", "Ceftamin", "Infubinol", "Ketapril", "Naftisol",
    "Placebo", "Propriva", "Ramicane", "Stelasyn", "Zoniferol"
]
marker = ["o", "x", ".", "v", "^", "<", "|", "1", "d", "+"]

d = sem_df["Drug"]
t = "Tumor Volume (mm3)"

df_slim = df_grouped[t]
plt.xlabel("Timepoint")
plt.ylabel(t)
x = df_slim.index
plt.grid(True, axis="y")
plt.title("Tumor Response to Treatment")

for i in range(len(drug)):
    y = df_slim[drug[i]]
    yerrs = sem_df[d == drug[i]][t]
    
    plt.errorbar(
        x, y, yerr=yerrs, marker=marker[i],
        markersize=5, label=drug[i], linestyle="dashed",
    )
plt.legend(loc="best", ncol=2, shadow=True, fontsize="small")
    
# Save the Figure
plt.savefig("tumor_response.png", dpi=300)

# Show Figure

# %% [markdown]
# ![Tumor Response to Treatment](../Images/treatment.png)

# %% [markdown]
# ## Metastatic Response to Treatment

# %%
# Store the Mean Met. Site Data Grouped by Drug and Timepoint
# Convert to DataFrame
meta_df = df.groupby(["Drug", "Timepoint"]).mean()
meta_df = meta_df.drop(columns=t)
meta_df
# Preview DataFrame
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.160000
#           10                 0.320000
#           15                 0.375000
#           20                 0.652174
# ...                               ...
# Zoniferol 25                 1.687500
#           30                 1.933333
#           35                 2.285714
#           40                 2.785714
#           45                 3.071429
#
# [100 rows x 1 columns]

# %%
# Store the Standard Error associated with Met. Sites Grouped by Drug and Timepoint 
# Convert to DataFrame
meta_sem = df.groupby(["Drug", "Timepoint"]).sem()
# Preview DataFrame
meta_sem = meta_sem.drop(columns=["Mouse ID", "Tumor Volume (mm3)"])
meta_sem
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.074833
#           10                 0.125433
#           15                 0.132048
#           20                 0.161621
# ...                               ...
# Zoniferol 25                 0.236621
#           30                 0.248168
#           35                 0.285714
#           40                 0.299791
#           45                 0.286400
#
# [100 rows x 1 columns]

# %%
meta_df_reset = meta_df.reset_index()
meta_df_reset
# Out:
#          Drug  Timepoint  Metastatic Sites
# 0   Capomulin          0          0.000000
# 1   Capomulin          5          0.160000
# 2   Capomulin         10          0.320000
# 3   Capomulin         15          0.375000
# 4   Capomulin         20          0.652174
# ..        ...        ...               ...
# 95  Zoniferol         25          1.687500
# 96  Zoniferol         30          1.933333
# 97  Zoniferol         35          2.285714
# 98  Zoniferol         40          2.785714
# 99  Zoniferol         45          3.071429
#
# [100 rows x 3 columns]

# %%
# Minor Data Munging to Re-Format the Data Frames
# Preview that Reformatting worked
df_slim # I'm pretty sure the dataframe you want me to display here is supposed to contain the Meta. vals
        # (not like the df example provided.) I've previewed both just in case, though.
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
# 25         39.939528  54.287674  55.715252  57.678982  56.731968  57.482574
# 30         38.769339  56.769517  58.299397  60.994507  59.559509  59.809063
# 35         37.816839  58.827548  60.742461  63.371686  62.685087  62.420615
# 40         36.958001  61.467895  63.162824  66.068580  65.600754  65.052675
# 45         36.236114  64.132421  65.755562  70.662958  69.265506  68.084082
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# ...

# %%
m = "Metastatic Sites"

meta_df_pivot = meta_df_reset.pivot(index="Timepoint", columns="Drug")
meta_df_slim = meta_df_pivot[m]
meta_df_slim
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.160000  0.380952   0.280000  0.304348  0.260870  0.375000
# 10          0.320000  0.600000   0.666667  0.590909  0.523810  0.833333
# 15          0.375000  0.789474   0.904762  0.842105  0.857143  1.250000
# 20          0.652174  1.111111   1.050000  1.210526  1.150000  1.526316
# 25          0.818182  1.500000   1.277778  1.631579  1.500000  1.941176
# 30          1.090909  1.937500   1.588235  2.055556  2.066667  2.266667
# 35          1.181818  2.071429   1.666667  2.294118  2.266667  2.642857
# 40          1.380952  2.357143   2.100000  2.733333  2.466667  3.166667
# 45          1.476190  2.692308   2.111111  3.363636  2.538462  3.272727
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# ...

# %%
# Generate the Plot (with Error Bars)
meta_sem = meta_sem.reset_index()

plt.xlabel("Timepoint")
plt.ylabel("Met. Sites")
x = meta_df_slim.index
plt.grid(True, axis="y")
plt.title("Metastatic Spread During Treatment")

for i in range(len(drug)):
    y = meta_df_slim[drug[i]]
    yerrs = meta_sem[d == drug[i]][m]
    
    plt.errorbar(
        x, y, yerr=yerrs, marker=marker[i],
        markersize=5, label=drug[i], linestyle="dashed",
    )
plt.legend(loc="best", ncol=2, shadow=True, fontsize="small")
    
# Save the Figure
plt.savefig("meta_spread.png", dpi=300)

# Show Figure
plt.show()

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/spread.png)

# %% [markdown]
# ## Survival Rates

# %%
# Store the Count of Mice Grouped by Drug and Timepoint (W can pass any metric)
c = "Count"
count_df = df.groupby(["Drug", "Timepoint"]).count()
# Convert to DataFrame
count_df = count_df.rename(columns={"Mouse ID": c}).drop(columns=[t, m]).reset_index()
# Preview DataFrame
count_df
# Out:
#          Drug  Timepoint  Count
# 0   Capomulin          0     25
# 1   Capomulin          5     25
# 2   Capomulin         10     25
# 3   Capomulin         15     24
# 4   Capomulin         20     23
# ..        ...        ...    ...
# 95  Zoniferol         25     16
# 96  Zoniferol         30     15
# 97  Zoniferol         35     14
# 98  Zoniferol         40     14
# 99  Zoniferol         45     14
#
# [100 rows x 3 columns]

# %%
# Minor Data Munging to Re-Format the Data Frames
count_df_slim = count_df.pivot(index="Timepoint", columns="Drug")
count_df_slim = count_df_slim[c]
# Preview the Data Frame
count_df_slim
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# Timepoint
# 0                 25        25         25        25        25       25
# 5                 25        21         25        23        23       24
# 10                25        20         21        22        21       24
# 15                24        19         21        19        21       20
# 20                23        18         20        19        20       19
# 25                22        18         18        19        18       17
# 30                22        16         17        18        15       15
# 35                22        14         12        17        15       14
# 40                21        14         10        15        15       12
# 45                21        13          9        11        13       11
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0                26        25        26         25
# 5                25        25        25         24
# ...

# %%
# Generate the Plot (Accounting for percentages)
plt.xlabel("Timepoint")
plt.ylabel("Survival Rate (%)")
x = meta_df_slim.index
plt.grid(True)
plt.title("Mouse Survival Rate")
for i in range(len(drug)):
    y = 100 * count_df_slim[drug[i]]/count_df_slim[drug[i]].max()
    plt.plot(
        x, y, marker=marker[i],
        markersize=5, label=drug[i], linestyle="dashed",
    )
plt.legend(loc="best", ncol=2, shadow=True, fontsize="small")
    
# Save the Figure
plt.savefig("survival_rate.png", dpi=300)
# Show the Figure
plt.show()

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/survival.png)

# %% [markdown]
# ## Summary Bar Graph

# %%
# Calculate the percent changes for each drug
perc_change = []
for i in range(len(drug)):
    perc_calc = 100 * (df_slim[drug[i]].values[len(df_slim[drug[i]]) - 1] - df_slim[drug[i]].values[0]) / df_slim[drug[i]].values[0]
    perc_change.append(perc_calc)

perc_drug = pd.DataFrame(zip(drug, perc_change), columns=["Drug", "Perc. Change"])

# Display the data to confirm
perc_drug
# Out:
#         Drug  Perc. Change
# 0  Capomulin    -19.475303
# 1   Ceftamin     42.516492
# 2  Infubinol     46.123472
# 3   Ketapril     57.028795
# 4   Naftisol     53.923347
# 5    Placebo     51.297960
# 6   Propriva     47.241175
# 7   Ramicane    -22.320900
# 8   Stelasyn     52.085134
# 9  Zoniferol     46.579751

# %%
drug_perc_tup = [(perc_drug["Drug"][i], perc_drug["Perc. Change"][i]) for i in (range(len(perc_drug)))]

# %%
# Store all Relevant Percent Changes into a Tuple
# Splice the data between passing and failing drugs
fig, ax = plt.subplots()
for i in range(len(drug)):
    facecolor = ""
    edgecolor = ""
    if (drug_perc_tup[i][1] <= 0):
        facecolor = "green"
        edgecolor = "lightgreen"

    else:
        facecolor = "red"
        edgecolor = "salmon"

    ax.bar(drug_perc_tup[i][0], drug_perc_tup[i][1],
            facecolor=facecolor, edgecolor=edgecolor, width=1,
           )
    
# Orient widths. Add labels, tick marks, etc. 
ax.grid(True, axis="y")
plt.xticks(rotation=60)
plt.xlabel("Drug")
plt.ylabel("Tumor Volume Change (%)")
plt.title("Tumor Change Over 45 Day Treatment")
ax.axhline(c='k')
# y = -4.5, 1.5
# x = -.16, 8.8
# magic num = .997
for i in range(10):
    if (i == 0 or i == 7):
        ax.text(-.45 + i, -4.5, str(round(drug_perc_tup[i][1], 1)) + "%",
                color="white", weight="heavy", fontsize=7.5)
    else:
        ax.text(-.45 + i, 1.5, str(round(drug_perc_tup[i][1], 1)) + "%",
                color="white", weight="heavy", fontsize=7.5)


# Use functions to label the percentages of changes


# Call functions to implement the function calls


# Save the Figure
plt.tight_layout()
plt.savefig("tumor_perc_change.png", dpi=300)

# Show the Figure
plt.show()

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/change.png)

# %%
# Three Observations from Visualizations

# 1) The drugs Capomulin and Ramicane were most effective in decreasing the volume
#    of tumors in the mice, thus increasing their survival percentage.
# 2) Propriva actually had a negative effect on mouse survivability since the observed survival
#    rate was lower than the placebo at almost every timepoint.
# 3) Ramicane was the most effective drug in decreasing tumor volume over the timeframe
#    (decrease from start volume by 22.3%). Ketapril was the least effective (increase in tumor
#    volume by 57%).
